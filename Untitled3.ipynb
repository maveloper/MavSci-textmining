# %%
# !pip install tweepy
# !pip install pymongo[str]

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from datetime import datetime
import json
from pymongo import MongoClient
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

# %%
consumer_key = "WP0MH64WBzyAHQLOofIOqzrpU"

# %%
consumer_secret = "oll1I0hcROhli054eoRN9o4NbA6GXFh63UuBtCPv8wlKbF9JVf"

# %%
access_token = "1184879854656856068-IibRmCEZgBZIypRDnSiJOAvaVHu029"

# %%
access_token_secret = "atMrbwfdk0OAes2oo1bgH5DhHOhvXKBBsUpR2X9AsS4vv"

# %%
auth = OAuthHandler(consumer_key, consumer_secret)

# %%
auth.set_access_token(access_token,access_token_secret)

# %%
# Class to listner tw data stream and store in mongoDB
class MyListener(StreamListener):
    def on_data(self, dados):
        tweet = json.loads(dados)
        created_at = tweet["created_at"]
        id_str = tweet["id_str"]
        text = tweet["text"]
        obj = {"created_at": created_at, "id_str": id_str, "text": text,}
        tweeting = collection.insert_one(obj).inserted_id
        print(obj)
        return True

# %%
mylistener = MyListener()

# %%
mystream = Stream(auth, listener = mylistener)

# %%
client = MongoClient('mongodb+srv://maveloper:tachikoma9@cluster0-jomy6.mongodb.net/test?retryWrites=true&w=majority')

# %%
#TW connection
db = client.twitterdb

# %%
collection = db.tweets

# %%
keywords = ['covid19', 'coronavirus', 'corona']

# %%
#Filter start and redording tweets in mongoDB
mystream.filter(track=keywords)
# Out:
# {'created_at': 'Thu May 28 23:23:57 +0000 2020', 'id_str': '1266148235426529280', 'text': 'Le Maroc marque son plein soutien à la réponse mondiale au coronavirus https://t.co/ZFaecGUOzG via @marocdiplomatique', '_id': ObjectId('5ed04813a801f7a59c49df39')}
# {'created_at': 'Thu May 28 23:23:57 +0000 2020', 'id_str': '1266148235460083718', 'text': 'RT @carolinaacarden: si el coronavirus no hubiera existido creo q este año si hubiera estado cool', '_id': ObjectId('5ed04814a801f7a59c49df3a')}
# {'created_at': 'Thu May 28 23:23:57 +0000 2020', 'id_str': '1266148235778940928', 'text': 'RT @TheGorgeousBaby: Covid19 está destruindo vidas,  empregos, famílias, sonhos, necessidades, a sociedade, cidades, estados, O PAÍS! \nAté…', '_id': ObjectId('5ed04814a801f7a59c49df3b')}
# {'created_at': 'Thu May 28 23:23:57 +0000 2020', 'id_str': '1266148235711639552', 'text': 'He absolutely should be held accountable just like Cuomo and the others', '_id': ObjectId('5ed04814a801f7a59c49df3c')}
# {'created_at': 'Thu May 28 23:23:57 +0000 2020', 'id_str': '1266148235204321281', 'text': '@FLOTUS @POTUS @VP @DHSgov @fema @NOAA Coronavirus disease lesson https://t.co/GXvuP0Jaih', '_id': ObjectId('5ed04814a801f7a59c49df3d')}
# {'created_at': 'Thu May 28 23:23:58 +0000 2020', 'id_str': '1266148236156260352', 'text': 'RT @maddow: With Missouri case numbers on the rise (again), state delays "Phase 2" of reopening from this upcoming Monday to Mid-June inste…', '_id': ObjectId('5ed04814a801f7a59c49df3e')}
# {'created_at': 'Thu May 28 23:23:58 +0000 2020', 'id_str': '1266148236378677253', 'text': 'RT @WalkingForEU: Spain is coming out of lock-down, had 2 recorded deaths in the last 2 days. Greece doing the same, 13 deaths in last 2 da…', '_id': ObjectId('5ed04815a801f7a59c49df3f')}
# {'created_at': 'Thu May 28 23:23:58 +0000 2020', 'id_str': '1266148236374478848', 'text': 'RT @krishgm: Dentists can start reopening from June 8th, if they dare  https://t.co/yQ7ZgxNVsD', '_id': ObjectId('5ed04815a801f7a59c49df40')}
# {'created_at': 'Thu May 28 23:23:58 +0000 2020', 'id_str': '1266148236378726401', 'text': 'RT @Merlo_Real: CORONAVIRUS: PREOCUPACIÓN DE LOS MEDICOS DE MERLO POR LA CRECIDA DE CASOS Y POR LA POCA INFORMACIÓN QUE BRINDA EL MUNICIPIO…', '_id': ObjectId('5ed04815a801f7a59c49df41')}
# {'created_at': 'Thu May 28 23:23:58 +0000 2020', 'id_str': '1266148
}
# {'created_at': 'Thu May 28 23:24:00 +0000 2020', 'id_str': '1266148246742724609', 'text': 'RT @LeninCamposC: El @GobEdoSLP y el gobierno federal han demostrado incapacidad para ayudar realmente a la población afectada por el coron…', '_id': ObjectId('5ed04825a801f7a59c49dfa2')}
# {'created_at': 'Thu May 28 23:24:00 +0000 2020', 'id_str': '1266148246663159808', 'text': 'RT @TomFitton: Biggest scandal in NY history -- nursing home deaths as result of Cuomo mandate! #coronavirus', '_id': ObjectId('5ed04825a801f7a59c49dfa3')}
# {'created_at': 'Thu May 28 23:24:00 +0000 2020', 'id_str': '1266148246679810050', 'text': 'RT @Poofesure: corona do what tho https://t.co/7Y9wxDr0aj', '_id': ObjectId('5ed04825a801f7a59c49dfa4')}
# {'created_at': 'Thu May 28 23:24:00 +0000 2020', 'id_str': '1266148246847619072', 'text': 'RT @MOV2DAGENERACIO: Se le vio el refajo al gobierno que manipula las estadísticas Covid19 para justificar la extensión estado excepción #D…', '_id': ObjectId('5ed04826a801f7a59c49dfa5')}
# {'created_at': 'Thu May 28 23:24:00 +0000 2020', 'id_str': '1266148246969126912', 'text': '@vazoachmad Bang pajoo sini main ke Jogja(setelah Corona) tak masakin gudeg wes wkwk', '_id': ObjectId('5ed04826a801f7a59c49dfa6')}
# {'created_at': 'Thu May 28 23:24:00 +0000 2020', 'id_str': '1266148246654763014', 'text': '188 casos confirmados de #Coronavirus y 34 muertos 💀 en las últimas 24 horas en #Tabasco. #YaNosLlevó.   Un finado… https://t.co/XBKP5ATrQ5', '_id': ObjectId('5ed04826a801f7a59c49dfa7')}
# {'created_at': 'Thu May 28 23:24:00 +0000 2020', 'id_str': '1266148247107706887', 'text': 'RT @CanAditude: 🇨🇦Canadians🇨🇦: \nTODAY, Minister of Health: Patty Hajdu was pressed hard on her (Liberal Government) spread of MISINFORMATIO…', '_id': ObjectId('5ed04826a801f7a59c49dfa8')}
# {'created_at': 'Thu May 28 23:24:00 +0000 2020', 'id_str': '1266148247178969090', 'text': 'RT @OiesamamadaZac: Ya se disparó el #Coronavirus en Zacatecas; 16 personas en tan solo un día 😮', '_id': ObjectId('5ed04826a801f7a59c49dfa9')}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-0f8a81f2480e> in <module>
#       1 #Filter start and redording tweets in mongoDB
# ----> 2 mystream.filter(track=keywords)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     349             next_status_obj = buf.read_len(length)
#     350             if self.running and next_status_obj:
# --> 351                 self._data(next_status_obj)
#     352
#     353             # # Note: keep-alive newlines might be inserted before each length value.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _data(self, data)
#     321
#     322     def _data(self, data):
# --> 323         if self.listener.on_data(data) is False:
#     324             self.running = False
#     325
#
# <ipython-input-8-26e6eb1711ec> in on_data(self, dados)
#       7         text = tweet["text"]
#       8         obj = {"created_at": created_at, "id_str": id_str, "text": text,}
# ----> 9         tweeting = collection.insert_one(obj).inserted_id
#      10         print(obj)
#      11         return True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session)
#     696                          write_concern=write_concern,
#     697                          bypass_doc_val=bypass_document_validation,
# --> 698                          session=session),
#     699             write_concern.acknowledged)
#     700
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     610             return self._insert_one(
#     611                 docs, ordered, check_keys, manipulate, write_concern, op_id,
# --> 612                 bypass_doc_val, session)
#     613
#     614         ids = []
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     598
#     599         self.__database.client._retryable_write(
# --> 600             acknowledged, _insert_command, session)
#     601
#     602         if not isinstance(doc, RawBSONDocument):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _retryable_write(self, retryable, func, session)
#    1489         """Internal retryable write helper."""
#    1490         with self._tmp_session(session) as s:
# -> 1491             return self._retry_with_session(retryable, func, s, None)
#    1492
#    1493     def _reset_server(self, address):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1382                             raise last_error
#    1383                         retryable = False
# -> 1384                     return func(session, sock_info, retryable)
#    1385             except ServerSelectionTimeoutError:
#    1386                 if is_retrying():
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in _insert_command(session, sock_info, retryable_write)
#     593                 session=session,
#     594                 client=self.__database.client,
# --> 595                 retryable_write=retryable_write)
#     596
#     597             _check_write_command_response(result)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields)
#     616         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     617         except BaseException as error:
# --> 618             self._raise_connection_failure(error)
#     619
#     620     def send_message(self, message, max_doc_size):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields)
#     611                            use_op_msg=self.op_msg_enabled,
#     612                            unacknowledged=unacknowledged,
# --> 613                            user_fields=user_fields)
#     614         except OperationFailure:
#     615             raise
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pymongo/network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields)
#     155             response_doc = {"ok": 1}
#     156         else:
# --> 157             reply = receive_message(sock, request_id)
#     158             unpacked_docs = reply.unpack_response(
#     159                 codec_options=codec_options, user_fields=user_fields)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pymongo/network.py in receive_message(sock, request_id, max_message_size)
#     194     # Ignore the response's request id.
#     195     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 196         _receive_data_on_socket(sock, 16))
#     197     # No request_id for exhaust cursor "getMore".
#     198     if request_id is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pymongo/network.py in _receive_data_on_socket(sock, length)
#     253         while bytes_read < length:
#     254             try:
# --> 255                 chunk_length = sock.recv_into(mv[bytes_read:])
#     256             except (IOError, OSError) as exc:
#     257                 if _errno_from_exception(exc) == errno.EINTR:
#
# ~/opt/anaconda3/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#Dataset with response data on mongoDB
dataset = [{"created_at": item["created_at"], "text": item["text"],} for item in collection.find()]

# %%
df = pd.DataFrame(dataset)

# %%
df
# Out:
#                          created_at  \
# 0    Thu May 28 22:57:10 +0000 2020
# 1    Thu May 28 22:57:10 +0000 2020
# 2    Thu May 28 22:57:10 +0000 2020
# 3    Thu May 28 22:57:10 +0000 2020
# 4    Thu May 28 22:57:10 +0000 2020
# ..                              ...
# 360  Thu May 28 23:24:00 +0000 2020
# 361  Thu May 28 23:24:00 +0000 2020
# 362  Thu May 28 23:24:00 +0000 2020
# 363  Thu May 28 23:24:00 +0000 2020
# 364  Thu May 28 23:24:00 +0000 2020
#
#                                                   text
# 0    RT @Breaking911: BREAKING: 2020 Boston Maratho...
# 1    RT @Ibelievein45: @GovWhitmer \nI work in nurs...
# 2    https://t.co/rfXyGmzRgj - #PremierLeague is ba...
# 3    RT @RepLeeZeldin: 🇺🇸Thank you @realDonaldTrump...
# 4    RT @TomFitton: Biggest scandal in NY history -...
# ..                                                 ...
# 360  @vazoachmad Bang pajoo sini main ke Jogja(sete...
# 361  188 casos confirmados de #Coronavirus y 34 mue...
# 362  RT @CanAditude: 🇨🇦Canadians🇨🇦: \nTODAY, Minist...
# 363  RT @OiesamamadaZac: Ya se disparó el #Coronavi...
# 364  RT @labubelah: GIVE AWAY\nkarena aku abis dibe...
#
# [365 rows x 2 columns]

# %%
cv = CountVectorizer()
count_matrix = cv.fit_transform(df.text)

# %%
word_count = pd.DataFrame(cv.get_feature_names(), columns=["word"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:50]
# Out:
#                word  count
# 0                rt    254
# 1               the    148
# 2             https    122
# 3                co    120
# 4                de    120
# 5       coronavirus     91
# 6                la     77
# 7                el     73
# 8                to     72
# 9                of     68
# 10               in     65
# 11          covid19     65
# 12              and     56
# 13               en     48
# 14               on     47
# 15              que     47
# 16              for     39
# 17               is     35
# 18               no     33
# 19               it     33
# 20              you     31
# 21           corona     30
# 22              are     29
# 23               we     27
# 24             with     24
# 25              los     24
# 26              por     23
# 27             from     22
# 28              con     22
# 29              las     22
# 30              del     22
# 31             have     21
# 32               as     20
# 33              not     20
# 34               un     20
# 35             para     19
# 36           deaths     18
# 37  realdonaldtrump     18
# 38              all     18
# 39             this     17
# 40            about     17
# 41              out     16
# 42               se     16
# 43             that     15
# 44             your     15
# 45             over     14
# 46               es     14
# 47              has     14
# 48            world     13
# 49              don     13
